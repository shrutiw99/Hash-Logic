# %%
n=int(input("enter a num"))
sum=0
while(n>0):
    digit=n%10
    sum=sum+digit
    n=n//10
    print("sum of digits",sum)
# Out:
# enter a num25
# sum of digits 5
# sum of digits 7

# %%
                                      #fibnoci series
    
x=0
y=1
for i in range(1,10):
    print(x)
    sum=(x+y)
    x=y
    y=sum
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
n=int(input("enter the number"))
p=0
for i in range(1,11):
    p=n*i
    print(n,"*",i,"=",p)
    i=i+1

# %%
for x in range(10):
    if x % 2 == 0:
        continue
    print(x)

# %%
for x in range(10):
    if x%2==0:
        break
        print(x)

# %%
for x in range(10):
    if x%2==0:
        print(x)
        break

# %%
count=0
while True:
    print(count)
    count+=1
    if count>=5:
        break

# %%
a=int(input("enter the number"))
count=0
while(a>0):
    digit=a%10
    count=count*10+digit
    a=a//10
    if(b==count):
        print("the no. is palindrome")
        else:
        print("not")
# Out:
#   File "<ipython-input-20-287f9e274749>", line 9
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
_shivani =3
print(_shivani)
a="shivani"
print(a)
# Out:
# 3
# shivani

# %%
print("hello")
print('hello')
print("'hello'")
print("\"hello\"")
print("hello\n""world")
# Out:
# hello
# hello
# 'hello'
# "hello"
#
# hello
# world
